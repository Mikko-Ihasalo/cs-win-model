# %%
import sys
from pathlib import Path
root = Path.cwd()
import os
# Get the project root directory
if (root / "utils").exists():
    project_root = root
elif (root.parent / "utils").exists():
    project_root = root.parent

sys.path.insert(0, str(project_root))

DEMO_FOLDER_PATH = "../../data/demos/"
DEMOS = os.listdir(DEMO_FOLDER_PATH)

from utils.demo_preprocessing import (
    parse_demo,
    save_parsed_data,
    parse_multiple_demos,
)

# %%
df = parse_multiple_demos(DEMO_FOLDER_PATH)
# Out:
# Demo  1  parsing complete.
# Demo  2  parsing complete.
# Demo  3  parsing complete.
# Demo  4  parsing complete.
# Parsing complete. 4 demos parsed.

# %%
save_parsed_data(df, "../../data/data/processed_demo.csv")
# Out:
# Parsed data saved to ../../data/data/processed_demo.csv
