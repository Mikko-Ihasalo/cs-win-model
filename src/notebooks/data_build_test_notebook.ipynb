# %%
# %pip install demoparser2
# Out:
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    -------- ------------------------------- 1.0/4.7 MB 6.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.1/4.7 MB 5.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.1/4.7 MB 5.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.6/4.7 MB 3.0 MB/s eta 0:00:01
#    ------------------------------- -------- 3.7/4.7 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 3.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.7 MB 6.4 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.7 MB 6.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.9/9.7 MB 6.5 MB/s eta 0:00:01
#    --------------------- ------------------ 5.2/9.7 MB 6.5 MB/s eta 0:00:01
# ...
